# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
#Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
#Reading whale returns
csvreader_whale = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(csvreader_whale)
whale_returns.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
#Count nulls
whale_returns.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
#Drop nulls
whale_returns = whale_returns.dropna()
whale_returns.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
#Set the index to the date
whale_returns = whale_returns.dropna()
whale_returns.set_index(pd.to_datetime(whale_returns['Date'], infer_datetime_format=True), inplace=True)
whale_returns.drop(columns =['Date'], inplace=True)
whale_returns.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
# 2015-03-11                   0.004012            0.005163
# 2015-03-12                   0.008265            0.010272
# 2015-03-13                  -0.002497           -0.001428
# 2015-03-16                   0.007901            0.003583
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# 2015-03-10                    -0.012079               -0.009739
# 2015-03-11                     0.003312               -0.001147
# 2015-03-12                     0.013117                0.010801
# 2015-03-13                    -0.003697               -0.008142
# 2015-03-16                     0.007953                0.008055

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
#Reading algorithmic returns
csvreader_algo = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(csvreader_algo)
algo_returns.head(10)
# Out:
#          Date    Algo 1    Algo 2
# 0  2014-05-28  0.001745       NaN
# 1  2014-05-29  0.003978       NaN
# 2  2014-05-30  0.004464       NaN
# 3  2014-06-02  0.005692       NaN
# 4  2014-06-03  0.005292       NaN
# 5  2014-06-04 -0.001838       NaN
# 6  2014-06-05  0.004062  0.013285
# 7  2014-06-06  0.001857  0.008284
# 8  2014-06-09 -0.005012  0.005668
# 9  2014-06-10  0.004406 -0.000735

# %%
#Count nulls
algo_returns.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
#Drop nulls
algo_returns = algo_returns.dropna()
algo_returns.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
#Set the index to the date
algo_returns.set_index(pd.to_datetime(algo_returns['Date'], infer_datetime_format=True), inplace=True)
algo_returns.drop(columns =['Date'], inplace=True)
algo_returns.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# 2014-06-12 -0.000028 -0.003841
# 2014-06-13  0.001917 -0.000814
# 2014-06-16  0.001084  0.001831
# 2014-06-17  0.000922  0.006870
# 2014-06-18 -0.006303  0.007228

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
#Reading S&P 500 Closing Prices
csvreader_sp500 = Path("Resources/sp500_history.csv")
sp500_closing_prices = pd.read_csv(csvreader_sp500)

# %%
#Check Data Types
sp500_closing_prices.dtypes
#sp500_closing_prices.head()
# Out:
# Date     object
# Close    object
# dtype: object

# %%
#Fix Data Types
sp500_closing_prices.set_index(pd.to_datetime(sp500_closing_prices['Date'], infer_datetime_format=True), inplace=True)
sp500_closing_prices.drop(columns =['Date'], inplace=True)
sp500_closing_prices['Close'] = sp500_closing_prices['Close'].str.replace('$', '')
sp500_closing_prices['Close'] = sp500_closing_prices['Close'].astype('float')
#sp500_closing_prices.head()
sp500_closing_prices.dtypes
# Out:
# /var/folders/82/szvr1kmj0hl1j121k98bfvch0000gn/T/ipykernel_21766/3924571678.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp500_closing_prices['Close'] = sp500_closing_prices['Close'].str.replace('$', '')
# Close    float64
# dtype: object

# %%
#Reverse the order of the index
sp500_closing_prices = sp500_closing_prices.iloc[::-1]

# %%
#Calculate Daily Returns
sp500_daily_returns = sp500_closing_prices.pct_change()
sp500_daily_returns.head()
#sp500_daily_returns.isnull().sum()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
#Drop nulls
sp500_daily_returns = sp500_daily_returns.dropna()
sp500_daily_returns.isnull().sum()
#sp500_daily_returns.head()
# Out:
# Close    0
# dtype: int64

# %%
#Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.rename(columns={'Close' : 'Daily Return'}, inplace=True) 
sp500_daily_returns.head()
# Out:
#             Daily Return
# Date
# 2012-10-02      0.000872
# 2012-10-03      0.003624
# 2012-10-04      0.007174
# 2012-10-05     -0.000322
# 2012-10-08     -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
#Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
#Joining dataframes
combined_returns_dataframe = sp500_daily_returns.join(whale_returns[['SOROS FUND MANAGEMENT LLC','PAULSON & CO.INC. ','TIGER GLOBAL MANAGEMENT LLC','BERKSHIRE HATHAWAY INC']], on='Date').join(algo_returns[['Algo 1','Algo 2']], on='Date')
#Renaming the columns for portfolio names
combined_returns_dataframe.columns = ['S&P 500 Return','SOROS FUND MANAGEMENT LLC Return','PAULSON & CO. INC. Return', 'TIGER GLOBAL MANAGEMENT LLC Return', 'BERKSHIRE HATHAWAY INC Return', 'Algo 1 Return', 'Algo 2 Return']
combined_returns_dataframe.sample(5)
# Out:
#             S&P 500 Return  SOROS FUND MANAGEMENT LLC Return  \
# Date
# 2013-10-24        0.003258                               NaN
# 2017-01-23       -0.002690                          0.000700
# 2013-01-04        0.004865                               NaN
# 2015-05-01        0.010923                          0.006051
# 2018-04-26        0.010434                          0.007127
#
#             PAULSON & CO. INC. Return  TIGER GLOBAL MANAGEMENT LLC Return  \
# Date
# 2013-10-24                        NaN                                 NaN
# 2017-01-23                  -0.005116                           -0.002111
# 2013-01-04                        NaN                                 NaN
# 2015-05-01                   0.002551                            0.006526
# 2018-04-26                   0.004416                            0.005724
#
#             BERKSHIRE HATHAWAY INC Return  Algo 1 Return  Algo 2 Return
# Date
# 2013-10-24                            NaN            NaN            NaN
# 2017-01-23                       0.009379      -0.006101      -0.001226
# 2013-01-04                            NaN            NaN            NaN
# 2015-05-01                       0.009650       0.005197       0.003263
# 2018-04-26                       0.018664      -0.003238       0.005543

# %%
#Remove nulls for standaridizing data
combined_returns_dataframe = combined_returns_dataframe.dropna()
combined_returns_dataframe.isnull().sum()
combined_returns_dataframe.head(5)
# Out:
#             S&P 500 Return  SOROS FUND MANAGEMENT LLC Return  \
# Date
# 2015-03-03       -0.004539                         -0.001266
# 2015-03-04       -0.004389                          0.002230
# 2015-03-05        0.001196                          0.004016
# 2015-03-06       -0.014174                         -0.007905
# 2015-03-09        0.003944                          0.000582
#
#             PAULSON & CO. INC. Return  TIGER GLOBAL MANAGEMENT LLC Return  \
# Date
# 2015-03-03                  -0.004981                           -0.000496
# 2015-03-04                   0.003241                           -0.002534
# 2015-03-05                   0.004076                            0.002355
# 2015-03-06                  -0.003574                           -0.008481
# 2015-03-09                   0.004225                            0.005843
#
#             BERKSHIRE HATHAWAY INC Return  Algo 1 Return  Algo 2 Return
# Date
# 2015-03-03                      -0.006569      -0.001942      -0.000949
# 2015-03-04                       0.004213      -0.008589       0.002416
# 2015-03-05                       0.006726      -0.000955       0.004323
# 2015-03-06                      -0.013098      -0.004957      -0.011460
# 2015-03-09                      -0.001652      -0.005447       0.001303

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
#Plot daily returns of all portfolios
combined_returns_dataframe.plot(figsize=(10,5),title="Daily Returns 2015 - 2019",ylabel="Daily Return",xlabel="Date")
# Out:
# <Axes: title={'center': 'Daily Returns 2015 - 2019'}, xlabel='Date', ylabel='Daily Return'>

# %%
#Plot each portfolio or index individually
combined_returns_dataframe["S&P 500 Return"].plot(figsize=(10,5),title="S&P 500 Daily Returns 2015 - 2019",ylabel="Daily Return",xlabel="Date")
# Out:
# <Axes: title={'center': 'S&P 500 Daily Returns 2015 - 2019'}, xlabel='Date', ylabel='Daily Return'>

# %%
#Plot each portfolio or index individually
combined_returns_dataframe["Algo 1 Return"].plot(figsize=(10,5),title="Algo 1 Daily Returns 2015 - 2019",ylabel="Daily Return",xlabel="Date")
# Out:
# <Axes: title={'center': 'Algo 1 Daily Returns 2015 - 2019'}, xlabel='Date', ylabel='Daily Return'>

# %%
#Plot each portfolio or index individually
combined_returns_dataframe["Algo 2 Return"].plot(figsize=(10,5),title="Algo 2 Daily Returns 2015 - 2019",ylabel="Daily Return",xlabel="Date")
# Out:
# <Axes: title={'center': 'Algo 2 Daily Returns 2015 - 2019'}, xlabel='Date', ylabel='Daily Return'>

# %%
#Plot each portfolio or index individually
combined_returns_dataframe["SOROS FUND MANAGEMENT LLC Return"].plot(figsize=(10,5),title="Soros Fund Management Daily Returns 2015 - 2019",ylabel="Daily Return",xlabel="Date")
# Out:
# <Axes: title={'center': 'Soros Fund Management Daily Returns 2015 - 2019'}, xlabel='Date', ylabel='Daily Return'>

# %%
#Plot each portfolio or index individually
combined_returns_dataframe["PAULSON & CO. INC. Return"].plot(figsize=(10,5),title="Paulson & Co. Daily Returns 2015 - 2019",ylabel="Daily Return",xlabel="Date")
# Out:
# <Axes: title={'center': 'Paulson & Co. Daily Returns 2015 - 2019'}, xlabel='Date', ylabel='Daily Return'>

# %%
#Plot each portfolio or index individually
combined_returns_dataframe["TIGER GLOBAL MANAGEMENT LLC Return"].plot(figsize=(10,5),title="Tiger Global Management Daily Returns 2015 - 2019",ylabel="Daily Return",xlabel="Date")
# Out:
# <Axes: title={'center': 'Tiger Global Management Daily Returns 2015 - 2019'}, xlabel='Date', ylabel='Daily Return'>

# %%
#Plot each portfolio or index individually
combined_returns_dataframe["BERKSHIRE HATHAWAY INC Return"].plot(figsize=(10,5),title="Berkshire Hathaway Daily Returns 2015 - 2019",ylabel="Daily Return",xlabel="Date")
# Out:
# <Axes: title={'center': 'Berkshire Hathaway Daily Returns 2015 - 2019'}, xlabel='Date', ylabel='Daily Return'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
#Calculate cumulative returns of all portfolios
cum_return_all = (1 + combined_returns_dataframe).cumprod()

#NOT NEEDED BUT SAVING FOR REFERENCE
#combined_returns_dataframe.columns = ['S&P 500 Return','SOROS FUND MANAGEMENT LLC Return','PAULSON & CO. INC. Return', 'TIGER GLOBAL MANAGEMENT LLC Return', 'BERKSHIRE HATHAWAY INC Return', 'Algo 1 Return', 'Algo 2 Return']
#cum_return_sp500 = (1 + combined_returns_dataframe_reversed['S&P 500 Return']).cumprod()
#cum_return_algo1 = (1 + combined_returns_dataframe_reversed['Algo 1 Return']).cumprod()
#cum_return_algo2 = (1 + combined_returns_dataframe_reversed['Algo 2 Return']).cumprod()
#cum_return_soros = (1 + combined_returns_dataframe_reversed['SOROS FUND MANAGEMENT LLC Return']).cumprod()
#cum_return_paulson = (1 + combined_returns_dataframe_reversed['PAULSON & CO. INC. Return']).cumprod()
#cum_return_tiger = (1 + combined_returns_dataframe_reversed['TIGER GLOBAL MANAGEMENT LLC Return']).cumprod()
#cum_return_berkshire = (1 + combined_returns_dataframe_reversed['BERKSHIRE HATHAWAY INC Return']).cumprod()

#Plot cumulative returns
cum_return_all.loc['2015-03-03':'2019-04-23'].plot(figsize=(10,5),title="Cumulative Return (2015 - 2019)",ylabel = "Return (%)", xlabel="Date")
# Out:
# <Axes: title={'center': 'Cumulative Return (2015 - 2019)'}, xlabel='Date', ylabel='Return (%)'>

# %% [markdown]
# ### RESULTS:
# The Berkshire Hathaway Inc portfolio outperforms the S&P 500. Additionally, Algo 1 also outperforms the S&P 500

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
#Box plot to visually show risk
#Box plot of all portfolios daily returns
combined_returns_dataframe.plot.box(figsize =(25,10), title="Box Plot of Daily Returns", )
# Out:
# <Axes: title={'center': 'Box Plot of Daily Returns'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
#Calculate the daily standard deviations of all portfolios
combined_std_dataframe = combined_returns_dataframe.std()
combined_std_dataframe
# Out:
# S&P 500 Return                        0.008554
# SOROS FUND MANAGEMENT LLC Return      0.007895
# PAULSON & CO. INC. Return             0.007023
# TIGER GLOBAL MANAGEMENT LLC Return    0.010894
# BERKSHIRE HATHAWAY INC Return         0.012919
# Algo 1 Return                         0.007620
# Algo 2 Return                         0.008342
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
#Calculate  the daily standard deviation of S&P 500
sp500_std = combined_returns_dataframe["S&P 500 Return"].std()
print(round(sp500_std,4))
#Determine which portfolios are riskier than the S&P 500
# Out:
# 0.0086

# %% [markdown]
# ### Results:
#
# TIGER GLOBAL MANAGEMENT LLC (0.010894 std.dev) and BERKSHIRE HATHAWAY INC (0.012919 std.dev) are riskier than the S&P 500

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
#Calculate the annualized standard deviation (252 trading days)
annualized_std = combined_std_dataframe * np.sqrt(252)
annualized_std
# Out:
# S&P 500 Return                        0.135786
# SOROS FUND MANAGEMENT LLC Return      0.125335
# PAULSON & CO. INC. Return             0.111488
# TIGER GLOBAL MANAGEMENT LLC Return    0.172936
# BERKSHIRE HATHAWAY INC Return         0.205077
# Algo 1 Return                         0.120967
# Algo 2 Return                         0.132430
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
#Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_returns_dataframe[['S&P 500 Return','SOROS FUND MANAGEMENT LLC Return','PAULSON & CO. INC. Return', 'TIGER GLOBAL MANAGEMENT LLC Return', 'BERKSHIRE HATHAWAY INC Return']].rolling(window=21).std().plot(figsize=(20,5),title="Rolling Standard Deviation 21-Days")
# Out:
# <Axes: title={'center': 'Rolling Standard Deviation 21-Days'}, xlabel='Date'>

# %%
#Plot the rolling standard deviation
combined_returns_dataframe[['SOROS FUND MANAGEMENT LLC Return','PAULSON & CO. INC. Return', 'TIGER GLOBAL MANAGEMENT LLC Return', 'BERKSHIRE HATHAWAY INC Return']].rolling(window=21).std().plot(figsize=(20,5),title="Rolling Standard Deviation 21-Days")
# Out:
# <Axes: title={'center': 'Rolling Standard Deviation 21-Days'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
#Calculate the correlation
#Use the `corr` function to calculate correlations for each portfolio, algo, and S&P 500
correlation = combined_returns_dataframe.corr()

#Display de correlation matrix
correlation
# Out:
#                                     S&P 500 Return  \
# S&P 500 Return                            1.000000
# SOROS FUND MANAGEMENT LLC Return          0.837864
# PAULSON & CO. INC. Return                 0.669732
# TIGER GLOBAL MANAGEMENT LLC Return        0.623946
# BERKSHIRE HATHAWAY INC Return             0.751371
# Algo 1 Return                             0.279494
# Algo 2 Return                             0.858764
#
#                                     SOROS FUND MANAGEMENT LLC Return  \
# S&P 500 Return                                              0.837864
# SOROS FUND MANAGEMENT LLC Return                            1.000000
# PAULSON & CO. INC. Return                                   0.699914
# TIGER GLOBAL MANAGEMENT LLC Return                          0.561243
# BERKSHIRE HATHAWAY INC Return                               0.754360
# Algo 1 Return                                               0.321211
# Algo 2 Return                                               0.826873
#
#                                     PAULSON & CO. INC. Return  \
# S&P 500 Return                                       0.669732
# SOROS FUND MANAGEMENT LLC Return                     0.699914
# PAULSON & CO. INC. Return                            1.000000
# TIGER GLOBAL MANAGEMENT LLC Return                   0.434479
# BERKSHIRE HATHAWAY INC Return                        0.545623
# Algo 1 Return                                        0.268840
# Algo 2 Return                                        0.678152
#
#                                     TIGER GLOBAL MANAGEMENT LLC Return  \
# S&P 500 Return                                                0.623946
# SOROS FUND MANAGEMENT LLC Return                              0.561243
# PAULSON & CO. INC. Return                                     0.434479
# TIGER GLOBAL MANAGEMENT LLC Return                            1.000000
# BERKSHIRE HATHAWAY INC Return                                 0.424423
# Algo 1 Return                                                 0.164387
# Algo 2 Return                                                 0.507414
#
#                                     BERKSHIRE HATHAWAY INC Return  \
# S&P 500 Return                                           0.751371
# SOROS FUND MANAGEMENT LLC Return                         0.754360
# PAULSON & CO. INC. Return                                0.545623
# TIGER GLOBAL MANAGEMENT LLC Return                       0.424423
# BERKSHIRE HATHAWAY INC Return                            1.000000
# Algo 1 Return                                            0.292033
# Algo 2 Return                                            0.688082
#
#                                     Algo 1 Return  Algo 2 Return
# S&P 500 Return                           0.279494       0.858764
# SOROS FUND MANAGEMENT LLC Return         0.321211       0.826873
# PAULSON & CO. INC. Return                0.268840       0.678152
# TIGER GLOBAL MANAGEMENT LLC Return       0.164387       0.507414
# BERKSHIRE HATHAWAY INC Return            0.292033       0.688082
# Algo 1 Return                            1.000000       0.288243
# Algo 2 Return                            0.288243       1.000000

# %%
#Heatmap to plot the correlations
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
#Scatter Plots to see individual correlation of portfolios and algos
combined_returns_dataframe.plot(kind='scatter', x='S&P 500 Return', y='Algo 2 Return', title ="S&P 500 & Algo 2 CORRELATION")
# Out:
# <Axes: title={'center': 'S&P 500 & Algo 2 CORRELATION'}, xlabel='S&P 500 Return', ylabel='Algo 2 Return'>

# %%
#Scatter Plots to see individual correlation of portfolios and algos
combined_returns_dataframe.plot(kind='scatter', x='S&P 500 Return', y='Algo 1 Return', title ="S&P 500 & Algo 1 CORRELATION")
# Out:
# <Axes: title={'center': 'S&P 500 & Algo 1 CORRELATION'}, xlabel='S&P 500 Return', ylabel='Algo 1 Return'>

# %%
#Scatter Plots to see individual correlation of portfolios and algos
combined_returns_dataframe.plot(kind='scatter', x='S&P 500 Return', y='BERKSHIRE HATHAWAY INC Return', title ="S&P 500 & BERKSHIRE HATHAWAY CORRELATION")
# Out:
# <Axes: title={'center': 'S&P 500 & BERKSHIRE HATHAWAY CORRELATION'}, xlabel='S&P 500 Return', ylabel='BERKSHIRE HATHAWAY INC Return'>

# %%
#Scatter Plots to see individual correlation of portfolios and algos
combined_returns_dataframe.plot(kind='scatter', x='S&P 500 Return', y='TIGER GLOBAL MANAGEMENT LLC Return', title ="S&P 500 & TIGER GLOBAL CORRELATION")
# Out:
# <Axes: title={'center': 'S&P 500 & TIGER GLOBAL CORRELATION'}, xlabel='S&P 500 Return', ylabel='TIGER GLOBAL MANAGEMENT LLC Return'>

# %%
#Scatter Plots to see individual correlation of portfolios and algos
combined_returns_dataframe.plot(kind='scatter', x='S&P 500 Return', y='PAULSON & CO. INC. Return', title ="S&P 500 & PAULSON CORRELATION")
# Out:
# <Axes: title={'center': 'S&P 500 & PAULSON CORRELATION'}, xlabel='S&P 500 Return', ylabel='PAULSON & CO. INC. Return'>

# %%
#Scatter Plots to see individual correlation of portfolios and algos
combined_returns_dataframe.plot(kind='scatter', x='S&P 500 Return', y='SOROS FUND MANAGEMENT LLC Return', title ="S&P 500 & SOROS FUND CORRELATION")
# Out:
# <Axes: title={'center': 'S&P 500 & SOROS FUND CORRELATION'}, xlabel='S&P 500 Return', ylabel='SOROS FUND MANAGEMENT LLC Return'>

# %% [markdown]
# ### Results:
# Soros Fund is a close mimic to S&P 500

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
#Calculate covariance of a single portfolio, using Berkshire Hathaway
berkshire_covariance = combined_returns_dataframe['BERKSHIRE HATHAWAY INC Return'].cov(combined_returns_dataframe['S&P 500 Return'])
#TEST
#berkshire_covariance

#Calculate variance of S&P 500
variance_sp500 = combined_returns_dataframe["S&P 500 Return"].var()
#TEST
#variance_sp500

#Computing beta
berkshire_beta = berkshire_covariance/variance_sp500
#TEST
#berkshire_beta

#Plot beta trend
#calculate rolling covariance for berkshire using 60 day window
rolling_berkshire_covariance = combined_returns_dataframe['BERKSHIRE HATHAWAY INC Return'].rolling(window=60).cov(combined_returns_dataframe['S&P 500 Return'])
#calculate rolling variance for S&P 500 using 60 day window
rolling_variance = combined_returns_dataframe['S&P 500 Return'].rolling(window=60).var()
#calculate 60-day rolling beta of Berkshire and plot the data
rolling_berkshire_beta = rolling_berkshire_covariance / rolling_variance
rolling_berkshire_beta.plot(figsize=(20,10), title="Rolling 60-day Beta of Berkshire Hathaway Portfolio")
# Out:
# <Axes: title={'center': 'Rolling 60-day Beta of Berkshire Hathaway Portfolio'}, xlabel='Date'>

# %%
#Calculate all rolling betas for all portfolios and plot (60-day)
rolling_berkshire_covariance = combined_returns_dataframe['BERKSHIRE HATHAWAY INC Return'].rolling(window=60).cov(combined_returns_dataframe['S&P 500 Return'])
rolling_tiger_covariance = combined_returns_dataframe['TIGER GLOBAL MANAGEMENT LLC Return'].rolling(window=60).cov(combined_returns_dataframe['S&P 500 Return'])
rolling_paulson_covariance = combined_returns_dataframe['PAULSON & CO. INC. Return'].rolling(window=60).cov(combined_returns_dataframe['S&P 500 Return'])
rolling_soros_covariance = combined_returns_dataframe['SOROS FUND MANAGEMENT LLC Return'].rolling(window=60).cov(combined_returns_dataframe['S&P 500 Return'])
#Calculate rolling variance for S&P 500 using 60 day window
rolling_variance = combined_returns_dataframe['S&P 500 Return'].rolling(window=60).var()
#Calculate 60-day rolling beta of Berkshire and plot the data
rolling_berkshire_beta = rolling_berkshire_covariance / rolling_variance
rolling_tiger_beta = rolling_tiger_covariance / rolling_variance
rolling_paulson_beta = rolling_paulson_covariance / rolling_variance
rolling_soros_beta = rolling_soros_covariance / rolling_variance

#Add all to the same chart using ax = 
ax = rolling_berkshire_beta.plot(figsize=(20,10), title="Rolling 60-day Beta of Portfolios")
rolling_tiger_beta.plot(ax=ax)
rolling_paulson_beta.plot(ax=ax)
rolling_soros_beta.plot(ax=ax)

#Set the legend
ax.legend(["BERKSHIRE HATHAWAY","TIGER GLOBAL MANAGEMENT","PAULSON & CO", "SOROS FUND MANAGEMENT"])

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
#Use `ewm` to calculate the rolling window 21 days for standard deviation
rolling_21_std_ewm = combined_returns_dataframe.ewm(com=21,adjust=True).std()
rolling_21_std_ewm[['SOROS FUND MANAGEMENT LLC Return','PAULSON & CO. INC. Return', 'TIGER GLOBAL MANAGEMENT LLC Return', 'BERKSHIRE HATHAWAY INC Return']].plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
#Annualized Sharpe Ratios
#Calculate Sharpe ratios with a risk free rate of 0 as none was provided
sharpe_ratios = ((combined_returns_dataframe.mean()) * 252) / (combined_returns_dataframe.std() * np.sqrt(252))
sharpe_ratios

#10 Year Treasury Rate (I:10YTCMR) is equal to 3.81% for Jun 30 2023 - source: https://ycharts.com/indicators/10_year_treasury_rate
# Out:
# S&P 500 Return                        0.648267
# SOROS FUND MANAGEMENT LLC Return      0.356417
# PAULSON & CO. INC. Return            -0.483570
# TIGER GLOBAL MANAGEMENT LLC Return   -0.121060
# BERKSHIRE HATHAWAY INC Return         0.621810
# Algo 1 Return                         1.378648
# Algo 2 Return                         0.501364
# dtype: float64

# %%
#Visualize the sharpe ratios as a bar plot
#Plot sharpe ratios as a bar chart
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algo 1: Algorithmic strategy 1 outperforms both the S&P 500 and all whale portfolios
#
# Algo 2: Algorithmic strategy 2 underperforms the S&P 500 and Berkshire Hathaway, but outperforms Soros Fund, Paulson & CO, and Tiger Global.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
#Reading data from 1st stock
csvreader_amazon = Path("Resources/danes_portfolio_amazon_v2.csv")
amazon_close = pd.read_csv(csvreader_amazon,index_col="Date", parse_dates=True, infer_datetime_format=True)
amazon_close.columns = ["AMZN"]
amazon_close.head()
# Out:
#                       AMZN
# Date
# 2015-03-02 16:00:00  19.28
# 2015-03-03 16:00:00  19.23
# 2015-03-04 16:00:00  19.14
# 2015-03-05 16:00:00  19.39
# 2015-03-06 16:00:00  19.00

# %%
#Reading data from 2nd stock
csvreader_ford = Path("Resources/danes_portfolio_ford_v2.csv")
ford_close = pd.read_csv(csvreader_ford,index_col="Date", parse_dates=True, infer_datetime_format=True)
ford_close.columns = ["F"]
ford_close.head()
# Out:
#                          F
# Date
# 2015-03-02 16:00:00  16.57
# 2015-03-03 16:00:00  16.17
# 2015-03-04 16:00:00  16.03
# 2015-03-05 16:00:00  16.11
# 2015-03-06 16:00:00  15.93

# %%
#Reading data from 3rd stock
csvreader_mdt = Path("Resources/danes_portfolio_mdt_v2.csv")
mdt_close = pd.read_csv(csvreader_mdt,index_col="Date", parse_dates=True, infer_datetime_format=True)
mdt_close.columns = ["MDT"]
mdt_close.head()
# Out:
#                        MDT
# Date
# 2015-03-02 16:00:00  78.83
# 2015-03-03 16:00:00  78.03
# 2015-03-04 16:00:00  78.19
# 2015-03-05 16:00:00  78.50
# 2015-03-06 16:00:00  76.48

# %%
#Reading data from 4th stock
csvreader_netflix = Path("Resources/danes_portfolio_netflix_v2.csv")
netflix_close = pd.read_csv(csvreader_netflix,index_col="Date", parse_dates=True, infer_datetime_format=True)
netflix_close.columns = ["NFLX"]
netflix_close.head()
# Out:
#                       NFLX
# Date
# 2015-03-02 16:00:00  68.61
# 2015-03-03 16:00:00  67.82
# 2015-03-04 16:00:00  67.11
# 2015-03-05 16:00:00  66.81
# 2015-03-06 16:00:00  64.87

# %%
#Reading data from 5th stock
csvreader_pnc = Path("Resources/danes_portfolio_pnc_v2.csv")
pnc_close = pd.read_csv(csvreader_pnc,index_col="Date", parse_dates=True, infer_datetime_format=True)
pnc_close.columns = ["PNC"]
pnc_close.head()
# Out:
#                        PNC
# Date
# 2015-03-02 16:00:00  92.95
# 2015-03-03 16:00:00  92.33
# 2015-03-04 16:00:00  92.07
# 2015-03-05 16:00:00  92.54
# 2015-03-06 16:00:00  93.73

# %%
#Combine all stocks in a single DataFrame
portfolio_df = pd.concat([amazon_close,ford_close,mdt_close,netflix_close,pnc_close],axis="columns",join="inner")
portfolio_df.head()
# Out:
#                       AMZN      F    MDT   NFLX    PNC
# Date
# 2015-03-02 16:00:00  19.28  16.57  78.83  68.61  92.95
# 2015-03-03 16:00:00  19.23  16.17  78.03  67.82  92.33
# 2015-03-04 16:00:00  19.14  16.03  78.19  67.11  92.07
# 2015-03-05 16:00:00  19.39  16.11  78.50  66.81  92.54
# 2015-03-06 16:00:00  19.00  15.93  76.48  64.87  93.73

# %%
#Reset Date index
#Complete by importing with: index_col="Date", parse_dates=True, and infer_datetime_format=True

#If I had ot do something like this, I would:
#portfolio_df = portfolio_df.reset_index()
#portfolio_df.drop(columns=["level_0","index"])
#portfolio_df.head()

# %%
#Reorganize portfolio data by having a column per symbol
#Complete by concat via columns with date as index already

#If I had ot do something like this, I would:
#portfolio_df = portfolio_df.pivot_table(values="Close Price", index="Trade DATE", columns="Symbol")

# %%
#Calculate daily returns & drop NAs
portfolio_returns = portfolio_df.pct_change().dropna()

#Display sample data
portfolio_returns.head()
# Out:
#                          AMZN         F       MDT      NFLX       PNC
# Date
# 2015-03-03 16:00:00 -0.002593 -0.024140 -0.010148 -0.011514 -0.006670
# 2015-03-04 16:00:00 -0.004680 -0.008658  0.002050 -0.010469 -0.002816
# 2015-03-05 16:00:00  0.013062  0.004991  0.003965 -0.004470  0.005105
# 2015-03-06 16:00:00 -0.020113 -0.011173 -0.025732 -0.029038  0.012859
# 2015-03-09 16:00:00 -0.003684  0.006277  0.005492 -0.018653  0.008535

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
#Set weights
weights = [1/5, 1/5, 1/5, 1/5, 1/5]

#Calculate portfolio return
portfolio_weighted_returns = portfolio_returns.dot(weights)
portfolio_weighted_returns_df = pd.DataFrame(portfolio_weighted_returns, columns=["Portfolio"])

#Display sample data
portfolio_weighted_returns_df.head()
# Out:
#                      Portfolio
# Date
# 2015-03-03 16:00:00  -0.011013
# 2015-03-04 16:00:00  -0.004915
# 2015-03-05 16:00:00   0.004530
# 2015-03-06 16:00:00  -0.014639
# 2015-03-09 16:00:00  -0.000407

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
#Join your returns DataFrame to the original returns DataFrame

#Convert the index to a datetime type
portfolio_weighted_returns_df.index = pd.to_datetime(portfolio_weighted_returns_df.index)
#Drop the minutes and hours from the timestamp index
portfolio_weighted_returns_df.index = portfolio_weighted_returns_df.index.floor('D')

#Join the two dataframes together
analysis_df = combined_returns_dataframe.join(portfolio_weighted_returns_df["Portfolio"], on='Date')

#Drop the un-needed items (Algo 1 & Algo 2)
analysis_df.drop(columns = ["Algo 1 Return", "Algo 2 Return"], inplace = True)

analysis_df.head()
# Out:
#             S&P 500 Return  SOROS FUND MANAGEMENT LLC Return  \
# Date
# 2015-03-03       -0.004539                         -0.001266
# 2015-03-04       -0.004389                          0.002230
# 2015-03-05        0.001196                          0.004016
# 2015-03-06       -0.014174                         -0.007905
# 2015-03-09        0.003944                          0.000582
#
#             PAULSON & CO. INC. Return  TIGER GLOBAL MANAGEMENT LLC Return  \
# Date
# 2015-03-03                  -0.004981                           -0.000496
# 2015-03-04                   0.003241                           -0.002534
# 2015-03-05                   0.004076                            0.002355
# 2015-03-06                  -0.003574                           -0.008481
# 2015-03-09                   0.004225                            0.005843
#
#             BERKSHIRE HATHAWAY INC Return  Portfolio
# Date
# 2015-03-03                      -0.006569  -0.011013
# 2015-03-04                       0.004213  -0.004915
# 2015-03-05                       0.006726   0.004530
# 2015-03-06                      -0.013098  -0.014639
# 2015-03-09                      -0.001652  -0.000407

# %%
#Only compare dates where return data exists for all the stocks (drop NaNs)
analysis_df.isnull().sum()

#No nulls, if I had to drop any:
#analysis_df.dropna
# Out:
# S&P 500 Return                        0
# SOROS FUND MANAGEMENT LLC Return      0
# PAULSON & CO. INC. Return             0
# TIGER GLOBAL MANAGEMENT LLC Return    0
# BERKSHIRE HATHAWAY INC Return         0
# Portfolio                             0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
#Calculate the annualized `std`
volatility = analysis_df.std() * np.sqrt(252)
volatility
# Out:
# S&P 500 Return                        0.135786
# SOROS FUND MANAGEMENT LLC Return      0.125335
# PAULSON & CO. INC. Return             0.111488
# TIGER GLOBAL MANAGEMENT LLC Return    0.172936
# BERKSHIRE HATHAWAY INC Return         0.205077
# Portfolio                             0.188067
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
#Calculate rolling standard deviation
rolling_std = analysis_df.rolling(window=21).std()

#Plot rolling standard deviation
rolling_std["Portfolio"].plot(figsize = (10,5), title="Std Deviation (Rolling 21-days) for Portfolio")
# Out:
# <Axes: title={'center': 'Std Deviation (Rolling 21-days) for Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
#Calculate and plot the correlation
correlation2 = analysis_df.corr()
correlation2
# Out:
#                                     S&P 500 Return  \
# S&P 500 Return                            1.000000
# SOROS FUND MANAGEMENT LLC Return          0.837864
# PAULSON & CO. INC. Return                 0.669732
# TIGER GLOBAL MANAGEMENT LLC Return        0.623946
# BERKSHIRE HATHAWAY INC Return             0.751371
# Portfolio                                 0.839750
#
#                                     SOROS FUND MANAGEMENT LLC Return  \
# S&P 500 Return                                              0.837864
# SOROS FUND MANAGEMENT LLC Return                            1.000000
# PAULSON & CO. INC. Return                                   0.699914
# TIGER GLOBAL MANAGEMENT LLC Return                          0.561243
# BERKSHIRE HATHAWAY INC Return                               0.754360
# Portfolio                                                   0.734167
#
#                                     PAULSON & CO. INC. Return  \
# S&P 500 Return                                       0.669732
# SOROS FUND MANAGEMENT LLC Return                     0.699914
# PAULSON & CO. INC. Return                            1.000000
# TIGER GLOBAL MANAGEMENT LLC Return                   0.434479
# BERKSHIRE HATHAWAY INC Return                        0.545623
# Portfolio                                            0.584336
#
#                                     TIGER GLOBAL MANAGEMENT LLC Return  \
# S&P 500 Return                                                0.623946
# SOROS FUND MANAGEMENT LLC Return                              0.561243
# PAULSON & CO. INC. Return                                     0.434479
# TIGER GLOBAL MANAGEMENT LLC Return                            1.000000
# BERKSHIRE HATHAWAY INC Return                                 0.424423
# Portfolio                                                     0.495364
#
#                                     BERKSHIRE HATHAWAY INC Return  Portfolio
# S&P 500 Return                                           0.751371   0.839750
# SOROS FUND MANAGEMENT LLC Return                         0.754360   0.734167
# PAULSON & CO. INC. Return                                0.545623   0.584336
# TIGER GLOBAL MANAGEMENT LLC Return                       0.424423   0.495364
# BERKSHIRE HATHAWAY INC Return                            1.000000   0.783659
# Portfolio                                                0.783659   1.000000

# %%
#Plot correlation
ax = sns.heatmap(correlation2, cmap="YlGnBu")
plt.title("Heatmap of Correlation for Portfolio & Individual Stocks", fontsize = 10)
plt.show()

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
#Calculate and plot Beta
#Import a new CSV of SP500 data for date range from Google Finance (S&P 60 TSX)
csvpathsp500 = Path("Resources/danes_portfolio_sp500_v2.csv")
sp500_p_close = pd.read_csv(csvpathsp500,index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_p_close.columns = ["S&P 500 - 60 TSX"]
sp500_returns = sp500_p_close.pct_change().dropna()
sp500_returns.head()
#Convert the index to a datetime type
sp500_returns.index = pd.to_datetime(sp500_returns.index)
#Drop the minutes and hours from the timestamp index
sp500_returns.index = sp500_returns.index.floor('D')

#Combine into one new dataframe
analysis2_df = pd.concat([analysis_df,sp500_returns],axis="columns",join="inner")
analysis2_df

#Drop original S&P 500 return
analysis2_df.drop(columns = "S&P 500 Return", inplace = True)
analysis2_df


#Calculate information for Beta
portfolio_covariance = analysis2_df["Portfolio"].cov(analysis2_df["S&P 500 - 60 TSX"])
sp500_variance = analysis2_df["S&P 500 - 60 TSX"].var()

#Calculate Beta
portfolio_beta = portfolio_covariance / sp500_variance
portfolio_beta

#Rolling Metrics
rolling_portfolio_covariance = analysis2_df["Portfolio"].rolling(window=60).cov(analysis2_df['S&P 500 - 60 TSX'])
rolling_sp500_variance = analysis2_df['S&P 500 - 60 TSX'].rolling(window=60).var()
rolling_portfolio_beta = rolling_portfolio_covariance / rolling_sp500_variance

#Plot the rolling Beta
rolling_portfolio_beta.plot(figsize=(10, 5), title='Rolling 60-Day Beta of Portfolio & S&P 500 - 60 TSX')
# Out:
# <Axes: title={'center': 'Rolling 60-Day Beta of Portfolio & S&P 500 - 60 TSX'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
#Calculate Annualized Sharpe Ratios
#Calculate Sharpe ratios with a risk free rate of 0
sharpe_ratios_2 = ((analysis2_df.mean()) * 252) / (analysis2_df.std() * np.sqrt(252))
sharpe_ratios_2
# Out:
# SOROS FUND MANAGEMENT LLC Return      0.279364
# PAULSON & CO. INC. Return            -0.567620
# TIGER GLOBAL MANAGEMENT LLC Return   -0.146844
# BERKSHIRE HATHAWAY INC Return         0.465672
# Portfolio                             0.907497
# S&P 500 - 60 TSX                      0.256283
# dtype: float64

# %%
#Visualize the sharpe ratios as a bar plot
sharpe_ratios_2.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %%
#Mock up $10K investment to see gains/losses over the period
initial_investment = 10000
analysis2_df_cumulative_returns = (1 + analysis2_df).cumprod()
analysis2_df_cumulative_profits = (initial_investment * analysis2_df_cumulative_returns)
analysis2_df_cumulative_profits.plot(figsize=(20,10), title="$10K investment scenario return")
# Out:
# <Axes: title={'center': '$10K investment scenario return'}, xlabel='Date'>

# %% [markdown]
# ### How does your portfolio do?
#
# My portfolio exhibits strong excess reward associated with the invesment when balancing the portfolio at equal shares and accounting for risk with a 0.9075 Sharpe Ratio.  The portfolio is strong correlation with the S&P 500 60 TSX, indicating performance moves with the index (correlations: 0.839750).  Looking forward, with a Beta of 0.96, the portfolio is relatively stable.  If I invested \$10,000 into the portfolio in 2015, by 2019, I would have netted close to \$20,000, a 100% return in 4 years.
